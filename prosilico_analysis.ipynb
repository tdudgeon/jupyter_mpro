# %%
import pandas as pd
import numpy as np

import plotly
import plotly.graph_objects as go
import plotly.express as px
import plotly.io as pio

from rdkit.Chem import PandasTools

# %%
# Set the default renderer to png as the data is huge and overwhelms the Javascript renderers
pio.renderers.default = 'png'

# %%
df = pd.read_csv('data/prosilico/16/predictions.csv.gz')
df.dtypes
# Out:
# Unnamed: 0      int64
# smiles         object
# CLint         float64
# fdiss         float64
# fu            float64
# Vss           float64
# fabs          float64
# dtype: object

# %% [markdown]
# The meaning of these columsn is as follows:
#
# - **CLint**: Intrinsic hepatic metabolic clearance
# - **fdiss**: Maximum in-vivo solubility/dissolution potential
# - **fu**: Fraction unbound in human plasma
# - **Vss**: Steady-state volume of distribution
# - **fabs**: Fraction absorbed

# %%
PandasTools.AddMoleculeColumnToFrame(df,'smiles','Molecule')
df.dtypes
# Out:
# Unnamed: 0      int64
# smiles         object
# CLint         float64
# fdiss         float64
# fu            float64
# Vss           float64
# fabs          float64
# Molecule       object
# dtype: object

# %%
df.head()
# Out:
#    Unnamed: 0                     smiles        CLint  fdiss        fu  \
# 0           1          BrC(Br)=Cc1ccncn1   169.824365  0.980  0.871406
# 1           2          BrC(Br)=Cc1cncnc1   134.896288  0.978  0.941922
# 2           3   BrC(CCC1CCCCC1)Cc1ccccn1  1548.816619  0.966  0.106225
# 3           4   BrC(CCC1CCCCC1)Cc1ccncc1  1258.925412  0.963  0.337455
# 4           5  BrC(CCCc1ccccc1)Cc1ccncc1  2187.761624  0.986  0.249190
#
#         Vss   fabs                                           Molecule
# 0  0.854476  0.830  <img data-content="rdkit/molecule" src="data:i...
# 1  0.953016  0.812  <img data-content="rdkit/molecule" src="data:i...
# 2  0.662217  0.915  <img data-content="rdkit/molecule" src="data:i...
# 3  0.727780  0.890  <img data-content="rdkit/molecule" src="data:i...
# 4  1.406048  0.978  <img data-content="rdkit/molecule" src="data:i...

# %%
fig = px.histogram(df, x="CLint")
fig.show()

# %%
fig = px.histogram(df, x="fdiss")
fig.show()

# %%
fig = px.histogram(df, x="fu")
fig.show()

# %%
fig = px.histogram(df, x="Vss")
fig.show()

# %%
fig = px.histogram(df, x="fabs")
fig.show()
